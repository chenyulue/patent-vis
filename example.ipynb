# %%
import mpl_extra.treemap as tr
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
# from importlib import reload
# reload(tr)

# %%
df = pd.read_csv('data/G20.csv')
df.head()
# Out:
#           region        country  gdp_mil_usd    hdi econ_classification  \
# 0         Africa   South Africa       384315  0.629          Developing
# 1  North America  United States     15684750  0.937            Advanced
# 2  North America         Canada      1819081  0.911            Advanced
# 3  North America         Mexico      1177116  0.775          Developing
# 4  South America         Brazil      2395968  0.730          Developing
#
#   hemisphere
# 0   Southern
# 1   Northern
# 2   Northern
# 3   Northern
# 4   Southern

# %%
fig, ax = plt.subplots(figsize=(7,7), dpi=100, subplot_kw=dict(aspect=1.156))

# ggplot(G20, aes(area = gdp_mil_usd, fill = hdi)) +
#   geom_treemap()

trc = tr.treemap(
    ax, df, area='gdp_mil_usd', fill='hdi', 
    rectprops={'ec':'w', 'lw':1},
                )
ax.axis('off')

cb = fig.colorbar(trc.mappable, ax=ax, shrink=0.5)

cb.ax.set_title('hdi')
cb.outline.set_edgecolor('w')

plt.show()

# %%
fig, ax = plt.subplots()

# ggplot(G20, aes(area = gdp_mil_usd, fill = hdi, label = country)) +
#   geom_treemap() +
#   geom_treemap_text(fontface = "italic", colour = "white", place = "centre",
#                     grow = TRUE

trc = tr.treemap(
    ax, df, area='gdp_mil_usd', fill='hdi', labels='country',
    rectprops={'ec':'w', 'lw':2},
    textprops={'c':'w', 'fontstyle':'italic',},
                )
#ax.axis('off')

# cb = fig.colorbar(trc.mappable, ax=ax, shrink=0.5)

# cb.ax.set_title('hdi')
# cb.outline.set_edgecolor('w')

plt.show()

# %%
from importlib import reload
reload(tr)

fig, ax = plt.subplots()

trc = tr.treemap(ax, df, area='gdp_mil_usd', fill='hdi', labels='country',
           levels=['region', 'country'],
           textprops={'c':'w', 'wrap':True,
                      'place':'top left', 'max_fontsize':20},
           rectprops={'ec':'w'},
           subgroup_rectprops={'region':{'ec':'grey', 'lw':2, 'fill':False,
                                         'zorder':5}},
           subgroup_textprops={'region':{'c':'k', 'alpha':0.5, 'fontstyle':'italic'}},
           )

#ax.legend(handles=trc.handles['region'], ncol=4, loc='lower left', bbox_to_anchor=(-0.1,-0.25))
#fig.colorbar(trc.mappable, ax)

plt.show()

# %%
from importlib import reload
reload(tr)

fig, ax = plt.subplots()

tr.treemap(ax, df, area=1, labels='country', 
           levels=['hemisphere', 'region', 'econ_classification', 'country'],
           textprops=dict(c='w', wrap=True, max_fontsize=12),
           rectprops=dict(ec='w', fc='grey'),
           subgroup_textprops={'hemisphere':dict(c='r', alpha=0.5),
                               'region':dict(c='w', alpha=0.5, fontstyle='italic',
                                             place='bottom center',
                                             max_fontsize=16),
                               'econ_classification':dict(place='top center', c='b', 
                                                          alpha=0.5, 
                                                          max_fontsize=16),},
           subgroup_rectprops={'hemisphere':dict(ec='r', lw=5, zorder=5, fill=False),
                               'region':dict(ec='w', lw=3, fill=False, zorder=4),
                               'econ_classification':dict(ec='b', zorder=3, fill=False)}
           )

plt.show()

# %%
# Out:
# 2.0

# %%
g = df.groupby(by=['一级'], sort=False).sum()
g.index
# Out:
# Index(['应用与服务', '人机交互', '芯片', '操作系统'], dtype='object', name='一级')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()
ax.set_xlim([0, 100])
ax.set_ylim([0, 100])

tr.treemap(ax, df, area='申请量/项', levels=['一级','二级'])
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9688\3299976811.py in <module>
#       6 ax.set_ylim([0, 100])
#       7
# ----> 8 tr.treemap(ax, df, area='申请量/项', levels=['一级','二级'])
#       9
#      10 plt.show()
#
# c:\Users\xj\py\patent-vis\mpl_extra\treemap.py in treemap(axes, data, area, labels, fill, cmap, levels, norm_x, norm_y, top, pad, subgroup_rectprops, subgroup_textprops, rectprops, textprops)
#      72                           subgroup_rectprops[k], subgroup_textprops[k], False)
#      73         elif (k == levels[-1]) or (k not in levels):
# ---> 74             draw_subgroup(axes, subgroup, top, norm_y, cmap,
#      75                           rectprops, textprops, True)
#      76
#
# c:\Users\xj\py\patent-vis\mpl_extra\treemap.py in draw_subgroup(axes, subgroup, top, height, cmap, rectprops, textprops, is_leaf)
#     106
#     107         rect = subgroup.loc[idx, '_area_']
# --> 108         y0 = height - rect['y'] - rect['dy'] if top else rect['y']
#     109         patch = mpatches.Rectangle(
#     110             (rect['x'], y0), rect['dx'], rect['dy'],
#
# IndexError: invalid index to scalar variable.

# %%
np.issubdtype(df.loc[:,'一级'].dtype, np.number)
# Out:
# False

# %%
subgroups['四级']
# Out:
#                             _area_  \
# 一级    二级      三级      四级
# 应用与服务 云端      云点播     NaN       13
#               云服务     NaN       13
#               云应用     NaN       13
#               云浏览     NaN       13
#               云存储     NaN       13
#       应用商店    广告      NaN       13
#               视频点播    NaN       13
#               支付      NaN       13
#               浏览器     NaN       13
# 人机交互  遥控      运动感应    光学传感      12
#                       超声定位      12
#                       惯性传感      12
#               基于便携终端  NaN       13
#               触碰板     NaN       12
#       人体识别    姿势      NaN       12
#               面部      NaN       12
#       语音控制    控制方式    NaN       12
#               语音识别    NaN       13
# 芯片    SOC     应用处理器   X86       12
#                       MIPS      12
#                       ARM       12
#               图形处理器   NaN       12
#       1+1方案   数字电视处理器 NaN       12
#               智能应用处理器 NaN       12
# 操作系统  其他      图形处理器   NaN       12
#       Linux   图形处理器   NaN       12
#       Windows 图形处理器   NaN       12
#       iOS     图形处理器   NaN       12
#       Android 图形处理器   NaN       12
#
#                                                                        _rect_
# 一级    二级      三级      四级
# 应用与服务 云端      云点播     NaN   {'x': 3, 'y': 3, 'dx': 14.008666047663258, 'dy...
#               云服务     NaN   {'x': 19.008666047663258, 'y': 3, 'dx': 14.008...
#               云应用     NaN   {'x': 3, 'y': 22.016740088105728, 'dx': 19.344...
#               云浏览     NaN   {'x': 3, 'y': 36.27929515418502, 'dx': 19.3448...
#               云存储     NaN   {'x': 24.34488806355101, 'y': 22.0167400881057...
#       应用商店    广告      NaN   {'x': 37.017332095326516, 'y': 3, 'dx': 10.606...
#               视频点播    NaN   {'x': 49.62426493345713, 'y': 3, 'dx': 10.6069...
#               支付      NaN   {'x': 37.017332095326516, 'y': 26.770925110132...
#               浏览器     NaN   {'x': 49.62426493345713, 'y': 26.7709251101321...
# 人机交互  遥控      运动感应    光学传感  {'x': 3, 'y': 54.54185022026432, 'dx': 19.9703...
#                       超声定位  {'x': 3, 'y': 66.66064851592404, 'dx': 19.9703...
#                       惯性传感  {'x': 22.97032160040516, 'y': 54.5418502202643...
#               基于便携终端  NaN   {'x': 3, 'y': 80.77944681158375, 'dx': 14.6168...
#               触碰板     NaN   {'x': 19.61685084831603, 'y': 80.7794468115837...
#       人体识别    姿势      NaN   {'x': 36.95548240060774, 'y': 78.2449878629866...
#               面部      NaN   {'x': 49.59334008609773, 'y': 78.2449878629866...
#       语音控制    控制方式    NaN   {'x': 50.09885439351734, 'y': 54.5418502202643...
#               语音识别    NaN   {'x': 36.95548240060774, 'y': 54.5418502202643...
# 芯片    SOC     应用处理器   X86   {'x': 66.23119777158774, 'y': 3, 'dx': 20.5125...
#                       MIPS  {'x': 66.23119777158774, 'y': 14.3863636363636...
#                       ARM   {'x': 86.74373259052925, 'y': 3, 'dx': 10.2562...
#               图形处理器   NaN   {'x': 66.23119777158774, 'y': 27.7727272727272...
#       1+1方案   数字电视处理器 NaN   {'x': 66.23119777158774, 'y': 38.0303030303030...
#               智能应用处理器 NaN   {'x': 82.61559888579387, 'y': 38.0303030303030...
# 操作系统  其他      图形处理器   NaN   {'x': 66.23119777158774, 'y': 57.5454545454545...
#       Linux   图形处理器   NaN   {'x': 83.61559888579387, 'y': 57.5454545454545...
#       Windows 图形处理器   NaN   {'x': 66.23119777158774, 'y': 74.9272727272727...
#       iOS     图形处理器   NaN   {'x': 66.23119777158774, 'y': 87.9636363636363...
#       Android 图形处理器   NaN   {'x': 89.41039925719593, 'y': 74.9272727272727...

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, how='right', right_on='rkey', left_on='lkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        5  foo        5
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        1  foo        8
# 5  foo        5  foo        8

# %%
df1.loc[:, df1.columns != '90']
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
