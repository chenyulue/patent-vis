# %%
import mpl_extra.treemap as tr
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
from importlib import reload
reload(tr)
# Out:
# <module 'mpl_extra.treemap' from 'c:\\Users\\xj\\py\\patent-vis\\mpl_extra\\treemap.py'>

# %%
df = pd.read_csv('data/Fig2-2-7.csv')
df = df.fillna('射频模块')

# %%
fig, ax = plt.subplots()

tr.treemap(ax, df, area='申请量/项', levels=['一级','二级'], norm_y=50, fill='一级', labels='二级', 
           top=True, 
           pad=(0,0,0,2.5),
           rectprops={'ec':'w', 'lw':2},
           textprops={'c':'k', 'fontfamily':'SimHei', 'wrap':True, })
    
plt.show()

# %%
x = df.groupby(by=['一级','二级'], sort=False, dropna=False).sum()
x.loc[('射频模块',pd.NA),:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    3079                     try:
# -> 3080                         return (self._engine.get_loc(key), None)
#    3081                     except KeyError as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.UInt64HashTable.get_item()
#
# ...

# %%
data = tr.get_plot_data(df, area='申请量/项', levels=['一级','二级'])
data.head()
# Out:
#      一级       二级  _area_
# 0  运算模块       定位      15
# 1  运算模块  多路径误差校正       4
# 2  运算模块       定时       1
# 3  运算模块       授时       1
# 4  基带模块    观测测量值       8

# %%
subgroups = tr.get_subgroups(data, levels=['一级','二级'])
subgroups['一级']
# Out:
#       _area_
# 一级
# 运算模块      21
# 基带模块      15
# 天线模块      10
# 应用         8
# 射频模块       1

# %%
sq = tr.squarify_subgroups(subgroups, 100, 100)

# %%
g = df.groupby(by=['一级'], sort=False).sum()
g.index
# Out:
# Index(['应用与服务', '人机交互', '芯片', '操作系统'], dtype='object', name='一级')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots()
ax.set_xlim([0, 100])
ax.set_ylim([0, 100])

tr.treemap(ax, df, area='申请量/项', levels=['一级','二级'])
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9688\3299976811.py in <module>
#       6 ax.set_ylim([0, 100])
#       7
# ----> 8 tr.treemap(ax, df, area='申请量/项', levels=['一级','二级'])
#       9
#      10 plt.show()
#
# c:\Users\xj\py\patent-vis\mpl_extra\treemap.py in treemap(axes, data, area, labels, fill, cmap, levels, norm_x, norm_y, top, pad, subgroup_rectprops, subgroup_textprops, rectprops, textprops)
#      72                           subgroup_rectprops[k], subgroup_textprops[k], False)
#      73         elif (k == levels[-1]) or (k not in levels):
# ---> 74             draw_subgroup(axes, subgroup, top, norm_y, cmap,
#      75                           rectprops, textprops, True)
#      76
#
# c:\Users\xj\py\patent-vis\mpl_extra\treemap.py in draw_subgroup(axes, subgroup, top, height, cmap, rectprops, textprops, is_leaf)
#     106
# ...

# %%
np.issubdtype(df.loc[:,'一级'].dtype, np.number)
# Out:
# False

# %%
subgroups['四级']
# Out:
#                             _area_  \
# 一级    二级      三级      四级
# 应用与服务 云端      云点播     NaN       13
#               云服务     NaN       13
#               云应用     NaN       13
#               云浏览     NaN       13
#               云存储     NaN       13
#       应用商店    广告      NaN       13
#               视频点播    NaN       13
#               支付      NaN       13
#               浏览器     NaN       13
# 人机交互  遥控      运动感应    光学传感      12
#                       超声定位      12
#                       惯性传感      12
#               基于便携终端  NaN       13
#               触碰板     NaN       12
#       人体识别    姿势      NaN       12
#               面部      NaN       12
#       语音控制    控制方式    NaN       12
#               语音识别    NaN       13
# 芯片    SOC     应用处理器   X86       12
#                       MIPS      12
#                       ARM       12
#               图形处理器   NaN       12
#       1+1方案   数字电视处理器 NaN       12
#               智能应用处理器 NaN       12
# 操作系统  其他      图形处理器   NaN       12
# ...

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, how='right', right_on='rkey', left_on='lkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        5  foo        5
# 2  bar        2  bar        6
# 3  baz        3  baz        7
# 4  foo        1  foo        8
# 5  foo        5  foo        8

# %%
df1.loc[:, df1.columns != '90']
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
